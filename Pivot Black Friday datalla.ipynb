# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.style.use('ggplot')

# %%
df=pd.read_csv('http://taanila.fi/BlackFriday.csv', encoding ='cp1252') 
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 7       1000004  P00346142      M  46-50           7             B
# 8       1000004   P0097242      M  46-50           7             B
# 9       1000005  P00274942      M  26-35          20             A
# 10      1000005  P00251242      M  26-35          20             A
# 11      1000005  P00014542      M  26-35          20             A
# 12      1000005  P00031342      M  26-35          20             A
# ...

# %%
df.pivot_table(df,index=['Product_Category_1','City_Category'])
# Out:
#                                   Marital_Status  Occupation  \
# Product_Category_1 City_Category
# 1                  A                    0.365004    7.971204
#                    B                    0.402703    8.173154
#                    C                    0.418020    8.623569
# 2                  A                    0.375021    8.138462
#                    B                    0.408507    8.070372
#                    C                    0.430223    8.753064
# 3                  A                    0.372334    7.677573
#                    B                    0.386837    7.655777
#                    C                    0.399422    8.314212
# 4                  A                    0.382176    7.821095
#                    B                    0.388662    7.836342
#                    C                    0.394152    8.235380
# 5                  A                    0.381794    7.669519
#                    B                    0.400161    7.934375
# ...

# %%
pd.pivot_table(df,index=['Product_Category_1','City_Category'], values=['Purchase'])
# Out:
#                                       Purchase
# Product_Category_1 City_Category
# 1                  A              13052.958064
#                    B              13435.245520
#                    C              14234.438760
# 2                  A              10908.784285
#                    B              11138.330154
#                    C              11715.659749
# 3                  A              10028.285981
#                    B               9999.386245
#                    C              10272.489805
# 4                  A               2267.251669
#                    B               2300.047175
#                    C               2426.236257
# 5                  A               6116.099708
#                    B               6166.109100
#                    C               6456.465122
# 6                  A              15515.002399
#                    B              15754.991317
#                    C              16224.043080
# ...

# %%
pd.pivot_table(df,index=['Product_Category_1'], values=['Purchase']).plot.barh(legend = False)
plt.xlabel('Purchase')
# Out:
# Text(0.5, 0, 'Purchase')

# %%
df.pivot_table(values = 'Purchase', index = 'Product_Category_1', columns = 'City_Category')
# Out:
# City_Category                  A             B             C
# Product_Category_1
# 1                   13052.958064  13435.245520  14234.438760
# 2                   10908.784285  11138.330154  11715.659749
# 3                   10028.285981   9999.386245  10272.489805
# 4                    2267.251669   2300.047175   2426.236257
# 5                    6116.099708   6166.109100   6456.465122
# 6                   15515.002399  15754.991317  16224.043080
# 7                   16220.233884  16364.494304  16602.306378
# 8                    7327.948466   7452.683661   7719.059388
# 9                   14831.357798  15681.720930  15964.211382
# 10                  19540.677123  19607.391519  19873.998821
# 11                   4577.355992   4609.152723   4887.166244
# 12                   1336.892617   1328.317354   1395.639358
# 13                    704.456151    713.699012    752.481891
# 14                  12660.677215  12966.072347  13990.396040
# ...
